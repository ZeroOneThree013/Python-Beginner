# %%
! pip install yfinance

# %%
import yfinance as yf
import pandas as pd

# %%
# start_date = '1990-01-01'
# end_date = '2025-03-31'
# period:日期範圍
# interval:頻率

# %%
ticker = 'NVDA' # ticker:股票代碼

# %%
data = yf.download(ticker, period='5y', interval='1d')
# Out:
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['NVDA']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')

# %%
data.head()
# Out:
# Price           Close       High        Low       Open  Volume
# Ticker        1104.TW    1104.TW    1104.TW    1104.TW 1104.TW
# Date
# 2015-04-01  16.109022  16.218235  15.999808  16.109022  429197
# 2015-04-02  16.245539  16.327449  16.109022  16.109022  535103
# 2015-04-07  16.491266  16.655086  16.300142  16.327445  970989
# 2015-04-08  16.545876  16.545876  16.300145  16.491270  480477
# 2015-04-09  16.272840  16.545874  16.245537  16.545874  758062

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# 1. 繪製 plot 格式化圖形尺寸 figsize.
#
# 2. 顯示標題 title，%s 表示字符串str()顯示，%行命令:於所在行生效。字體尺寸 fontsize 為16。
#
# 3. X軸與Y軸標籤的字體尺寸 fontsize 為14。
#
# 4. 設定網格 grid 的尺度 which 為主刻度 major、顏色為黑色 k、線型態為'-.'、與線寬尺寸 linewidth.
#
# 5. 顯示出圖像show。

# %%
data['Close'].plot(figsize=(10, 7))
plt.title('Close Price of %s' % ticker, fontsize=16)
plt.ylabel('Price', fontsize=14)
plt.xlabel('year', fontsize=14)
plt.grid(which='major', color='k', linestyle='-.', linewidth=0.5)
plt.show()

# %% [markdown]
# # 下載多家股票

# %%
import yfinance as yf
import pandas as pd

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
tickers_list = ['2308.TW', '2317.TW', '2353.TW']

# %%
data0 = pd.DataFrame(columns=tickers_list)

# %%
for ticker in tickers_list:
    data0[ticker] = yf.download(ticker, period='10y', interval='1d')['Close']
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
data0.head()
# Out:
#                2308.TW    2317.TW    2353.TW
# Date
# 2015-04-01  143.613327  66.174805  13.238564
# 2015-04-02  145.454529  67.257271  13.238564
# 2015-04-07  143.981552  67.545937  13.336627
# 2015-04-08  142.140366  67.618095  13.107813
# 2015-04-09  141.403885  67.112953  13.140502

# %%
data0.plot(figsize=(10, 7))
plt.legend()
plt.title('Close Price', fontsize=16)
plt.ylabel('Price', fontsize=14)
plt.xlabel('year', fontsize=14)
plt.grid(which='major', color='k', linestyle='-.', linewidth=0.5)
plt.show()
